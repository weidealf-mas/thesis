# %%
import sys
sys.path.append('../../ml_utils')

import config as cfg
import data_utils as du
import autoencoder as aenc
import timeit

import keras
import sklearn
from sklearn.model_selection import train_test_split

import pandas as pd
import numpy as np

import os
os.environ['CUDA_VISIBLE_DEVICES']='-1'
# Out:
# Using TensorFlow backend.
# /home/administrator/anaconda3/envs/masterthesis/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/administrator/anaconda3/envs/masterthesis/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/administrator/anaconda3/envs/masterthesis/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/administrator/anaconda3/envs/masterthesis/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/administrator/anaconda3/envs/masterthesis/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/administrator/anaconda3/envs/masterthesis/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
print("Python: ", sys.version)
print("pandas: ", pd.__version__)
print("numpy: ", np.__version__)
print("Keras: ", keras.__version__)
# Out:
# Python:  3.7.5 (default, Oct 25 2019, 15:51:11)
# [GCC 7.3.0]
# pandas:  0.25.3
# numpy:  1.17.4
# Keras:  2.2.4

# %% [markdown]
# ### Load and clean the data

# %%
log_data = './../../shared/data/swissid_authorize_logs_april_to_sept_2019.csv'

start = timeit.default_timer()
df = pd.read_csv(filepath_or_buffer=log_data, header=0, sep='\t', names=cfg.complete_feature_list, index_col=None)
stop = timeit.default_timer()

print("Original data frame size: {}\n".format(df.shape))
print("Time: {} seconds\n".format(stop - start))
# Out:
# Original data frame size: (12417597, 31)
#
# Time: 39.18794764500126 seconds

# %%
df = du.clean_data(df)
# Out:
# columns with NaN: loc_country_code
# loc_country_code is fixed

# %%
features = ['label_nr', 'src_software_sub_type', 'src_operating_system_name', 'src_hardware_type', 'response_status_code', 
            'oidc_client_id', 'oidc_scopes', 'oidc_ui_locales', 'loc_city', 'loc_country_code', 'date_weekday']

excludes = list(set(df.columns.tolist()) - set(features))

# %%
reduced_df = du.reduce_features(df, excludes)

print("reduced data frame size: {}\n".format(reduced_df.shape))
#display(reduced_df)
# Out:
# reduced data frame size: (12204748, 11)

# %%
print(reduced_df['label_nr'].value_counts())
# Out:
# 2    7412813
# 0    4769169
# 1      22766
# Name: label_nr, dtype: int64

# %%
def create_model(optimizer='adam', activation='relu'):
    
    model = aenc.create_simple_auto_encoder(10, 4, activation)
    model.compile(optimizer=optimizer, loss='mean_squared_error', metrics=['mae', 'accuracy'])

    return model

# %%
np.random.seed(7)

sample_size= 200000
exclude = ['label_nr']

# load dataset
X_df, y_df, anomaly_rate, encoder = du.build_normal_anomaly_sample_df(reduced_df, sample_size, exclude, True, True, False, True)
x_train, x_test, y_train, y_test = train_test_split(X_df, y_df, test_size=0.2, random_state=42)

# %%
from sklearn.model_selection import GridSearchCV
from keras.wrappers.scikit_learn import KerasClassifier


model = KerasClassifier(build_fn=create_model, 
                        epochs=20, 
                        batch_size=32, 
                        verbose=2, 
                        shuffle=True)

# define the grid search parameters
optimizer = ['RMSprop', 'Adadelta', 'Adam', 'Adamax']
activation = ['softmax', 'relu', 'tanh', 'sigmoid']
batch_size = [32, 64, 128]
epochs = [50, 100, 150]

param_grid = dict(optimizer=optimizer, batch_size=batch_size, epochs=epochs, activation=activation)
grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=-1, cv=3)

start = timeit.default_timer()
grid_result = grid.fit(x_train, x_train)
stop = timeit.default_timer()

# summarize results
print("Time: {} minutes\n".format((stop - start)/60))
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']

for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# WARNING:tensorflow:From /home/administrator/anaconda3/envs/masterthesis/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /home/administrator/anaconda3/envs/masterthesis/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/150
#  - 3s - loss: 0.8958 - mean_absolute_error: 0.5039 - acc: 0.5176
# Epoch 2/150
#  - 3s - loss: 0.8537 - mean_absolute_error: 0.4805 - acc: 0.7114
# Epoch 3/150
#  - 3s - loss: 0.8346 - mean_absolute_error: 0.4782 - acc: 0.7500
# Epoch 4/150
#  - 3s - loss: 0.8320 - mean_absolute_error: 0.4757 - acc: 0.7351
# Epoch 5/150
#  - 3s - loss: 0.8284 - mean_absolute_error: 0.4746 - acc: 0.7811
# Epoch 6/150
#  - 3s - loss: 0.8236 - mean_absolute_error: 0.4741 - acc: 0.8342
# Epoch 7/150
#  - 3s - loss: 0.8218 - mean_absolute_error: 0.4734 - acc: 0.8491
# Epoch 8/150
#  - 3s - loss: 0.8214 - mean_absolute_error: 0.4731 - acc: 0.8476
# Epoch 9/150
#  - 3s - loss: 0.8211 - mean_absolute_error: 0.4730 - acc: 0.8433
# Epoch 10/150
#  - 3s - loss: 0.8209 - mean_absolute_error: 0.4730 - acc: 0.8433
# Epoch 11/150
#  - 3s - loss: 0.8208 - mean_absolute_error: 0.4729 - acc: 0.8436
# Epoch 12/150
#  - 3s - loss: 0.8206 - mean_absolute_error: 0.4729 - acc: 0.8420
# Epoch 13/150
#  - 3s - loss: 0.8205 - mean_absolute_error: 0.4728 - acc: 0.8445
# Epoch 14/150
#  - 3s - loss: 0.8203 - mean_absolute_error: 0.4728 - acc: 0.8447
# Epoch 15/150
#  - 3s - loss: 0.8202 - mean_absolute_error: 0.4728 - acc: 0.8439
# Epoch 16/150
#  - 3s - loss: 0.8200 - mean_absolute_error: 0.4728 - acc: 0.8455
# Epoch 17/150
#  - 3s - loss: 0.8197 - mean_absolute_error: 0.4728 - acc: 0.8445
# Epoch 18/150
#  - 3s - loss: 0.8194 - mean_absolute_error: 0.4727 - acc: 0.8452
# Epoch 19/150
#  - 3s - loss: 0.8190 - mean_absolute_error: 0.4728 - acc: 0.8473
# Epoch 20/150
#  - 3s - loss: 0.8185 - mean_absolute_error: 0.4728 - acc: 0.8470
# Epoch 21/150
#  - 3s - loss: 0.8180 - mean_absolute_error: 0.4728 - acc: 0.8476
# Epoch 22/150
#  - 3s - loss: 0.8176 - mean_absolute_error: 0.4728 - acc: 0.8475
# Epoch 23/150
#  - 3s - loss: 0.8171 - mean_absolute_error: 0.4728 - acc: 0.8490
# Epoch 24/150
#  - 3s - loss: 0.8166 - mean_absolute_error: 0.4728 - acc: 0.8499
# Epoch 25/150
#  - 3s - loss: 0.8163 - mean_absolute_error: 0.4728 - acc: 0.8478
# Epoch 26/150
#  - 3s - loss: 0.8160 - mean_absolute_error: 0.4729 - acc: 0.8493
# Epoch 27/150
#  - 3s - loss: 0.8158 - mean_absolute_error: 0.4730 - acc: 0.8492
# Epoch 28/150
#  - 3s - loss: 0.8156 - mean_absolute_error: 0.4731 - acc: 0.8491
# Epoch 29/150
#  - 3s - loss: 0.8155 - mean_absolute_error: 0.4731 - acc: 0.8497
# Epoch 30/150
#  - 3s - loss: 0.8154 - mean_absolute_error: 0.4731 - acc: 0.8504
# Epoch 31/150
#  - 3s - loss: 0.8154 - mean_absolute_error: 0.4731 - acc: 0.8484
# Epoch 32/150
#  - 3s - loss: 0.8153 - mean_absolute_error: 0.4731 - acc: 0.8478
# Epoch 33/150
#  - 3s - loss: 0.8153 - mean_absolute_error: 0.4731 - acc: 0.8482
# Epoch 34/150
#  - 3s - loss: 0.8152 - mean_absolute_error: 0.4731 - acc: 0.8486
# Epoch 35/150
#  - 3s - loss: 0.8152 - mean_absolute_error: 0.4731 - acc: 0.8487
# Epoch 36/150
#  - 3s - loss: 0.8152 - mean_absolute_error: 0.4731 - acc: 0.8492
# Epoch 37/150
#  - 3s - loss: 0.8151 - mean_absolute_error: 0.4731 - acc: 0.8510
# Epoch 38/150
#  - 3s - loss: 0.8151 - mean_absolute_error: 0.4731 - acc: 0.8541
# Epoch 39/150
#  - 3s - loss: 0.8151 - mean_absolute_error: 0.4731 - acc: 0.8505
# Epoch 40/150
#  - 3s - loss: 0.8151 - mean_absolute_error: 0.4731 - acc: 0.8514
# Epoch 41/150
#  - 3s - loss: 0.8151 - mean_absolute_error: 0.4731 - acc: 0.8501
# Epoch 42/150
#  - 3s - loss: 0.8151 - mean_absolute_error: 0.4731 - acc: 0.8514
# Epoch 43/150
#  - 3s - loss: 0.8150 - mean_absolute_error: 0.4731 - acc: 0.8526
# Epoch 44/150
#  - 3s - loss: 0.8150 - mean_absolute_error: 0.4730 - acc: 0.8507
# Epoch 45/150
#  - 3s - loss: 0.8150 - mean_absolute_error: 0.4730 - acc: 0.8524
# Epoch 46/150
#  - 3s - loss: 0.8150 - mean_absolute_error: 0.4730 - acc: 0.8520
# Epoch 47/150
#  - 3s - loss: 0.8150 - mean_absolute_error: 0.4730 - acc: 0.8542
# Epoch 48/150
#  - 3s - loss: 0.8150 - mean_absolute_error: 0.4730 - acc: 0.8519
# Epoch 49/150
#  - 3s - loss: 0.8150 - mean_absolute_error: 0.4730 - acc: 0.8527
# Epoch 50/150
#  - 3s - loss: 0.8150 - mean_absolute_error: 0.4730 - acc: 0.8521
# Epoch 51/150
#  - 3s - loss: 0.8150 - mean_absolute_error: 0.4730 - acc: 0.8523
# Epoch 52/150
#  - 3s - loss: 0.8149 - mean_absolute_error: 0.4730 - acc: 0.8512
# Epoch 53/150
#  - 3s - loss: 0.8149 - mean_absolute_error: 0.4730 - acc: 0.8517
# Epoch 54/150
#  - 3s - loss: 0.8149 - mean_absolute_error: 0.4730 - acc: 0.8527
# Epoch 55/150
#  - 3s - loss: 0.8149 - mean_absolute_error: 0.4730 - acc: 0.8522
# Epoch 56/150
#  - 3s - loss: 0.8149 - mean_absolute_error: 0.4730 - acc: 0.8516
# Epoch 57/150
#  - 3s - loss: 0.8149 - mean_absolute_error: 0.4730 - acc: 0.8550
# Epoch 58/150
#  - 3s - loss: 0.8149 - mean_absolute_error: 0.4730 - acc: 0.8511
# Epoch 59/150
#  - 3s - loss: 0.8149 - mean_absolute_error: 0.4730 - acc: 0.8539
# Epoch 60/150
#  - 3s - loss: 0.8149 - mean_absolute_error: 0.4730 - acc: 0.8540
# Epoch 61/150
#  - 3s - loss: 0.8149 - mean_absolute_error: 0.4730 - acc: 0.8569
# Epoch 62/150
#  - 3s - loss: 0.8149 - mean_absolute_error: 0.4730 - acc: 0.8530
# Epoch 63/150
#  - 3s - loss: 0.8149 - mean_absolute_error: 0.4730 - acc: 0.8532
# Epoch 64/150
#  - 3s - loss: 0.8149 - mean_absolute_error: 0.4730 - acc: 0.8530
# Epoch 65/150
#  - 3s - loss: 0.8149 - mean_absolute_error: 0.4730 - acc: 0.8555
# Epoch 66/150
#  - 3s - loss: 0.8149 - mean_absolute_error: 0.4730 - acc: 0.8536
# Epoch 67/150
#  - 3s - loss: 0.8149 - mean_absolute_error: 0.4730 - acc: 0.8543
# Epoch 68/150
#  - 3s - loss: 0.8149 - mean_absolute_error: 0.4730 - acc: 0.8538
# Epoch 69/150
#  - 3s - loss: 0.8149 - mean_absolute_error: 0.4730 - acc: 0.8517
# Epoch 70/150
#  - 3s - loss: 0.8149 - mean_absolute_error: 0.4730 - acc: 0.8531
# Epoch 71/150
#  - 3s - loss: 0.8149 - mean_absolute_error: 0.4730 - acc: 0.8531
# Epoch 72/150
#  - 3s - loss: 0.8149 - mean_absolute_error: 0.4730 - acc: 0.8515
# Epoch 73/150
#  - 3s - loss: 0.8149 - mean_absolute_error: 0.4730 - acc: 0.8538
# Epoch 74/150
#  - 3s - loss: 0.8149 - mean_absolute_error: 0.4730 - acc: 0.8520
# Epoch 75/150
#  - 3s - loss: 0.8149 - mean_absolute_error: 0.4730 - acc: 0.8523
# Epoch 76/150
#  - 3s - loss: 0.8149 - mean_absolute_error: 0.4730 - acc: 0.8526
# Epoch 77/150
#  - 3s - loss: 0.8149 - mean_absolute_error: 0.4730 - acc: 0.8558
# Epoch 78/150
#  - 3s - loss: 0.8149 - mean_absolute_error: 0.4730 - acc: 0.8500
# Epoch 79/150
#  - 3s - loss: 0.8149 - mean_absolute_error: 0.4730 - acc: 0.8552
# Epoch 80/150
#  - 3s - loss: 0.8149 - mean_absolute_error: 0.4730 - acc: 0.8536
# Epoch 81/150
#  - 3s - loss: 0.8149 - mean_absolute_error: 0.4730 - acc: 0.8544
# Epoch 82/150
#  - 3s - loss: 0.8149 - mean_absolute_error: 0.4730 - acc: 0.8539
# Epoch 83/150
#  - 3s - loss: 0.8149 - mean_absolute_error: 0.4730 - acc: 0.8543
# Epoch 84/150
#  - 3s - loss: 0.8149 - mean_absolute_error: 0.4730 - acc: 0.8541
# Epoch 85/150
#  - 3s - loss: 0.8149 - mean_absolute_error: 0.4730 - acc: 0.8532
# Epoch 86/150
#  - 3s - loss: 0.8149 - mean_absolute_error: 0.4730 - acc: 0.8536
# Epoch 87/150
#  - 3s - loss: 0.8149 - mean_absolute_error: 0.4730 - acc: 0.8541
# Epoch 88/150
#  - 3s - loss: 0.8149 - mean_absolute_error: 0.4730 - acc: 0.8529
# Epoch 89/150
#  - 3s - loss: 0.8149 - mean_absolute_error: 0.4730 - acc: 0.8538
# Epoch 90/150
#  - 3s - loss: 0.8149 - mean_absolute_error: 0.4730 - acc: 0.8547
# Epoch 91/150
#  - 3s - loss: 0.8149 - mean_absolute_error: 0.4730 - acc: 0.8527
# Epoch 92/150
#  - 3s - loss: 0.8149 - mean_absolute_error: 0.4730 - acc: 0.8534
# Epoch 93/150
#  - 3s - loss: 0.8149 - mean_absolute_error: 0.4730 - acc: 0.8542
# Epoch 94/150
#  - 3s - loss: 0.8149 - mean_absolute_error: 0.4730 - acc: 0.8537
# Epoch 95/150
#  - 3s - loss: 0.8149 - mean_absolute_error: 0.4730 - acc: 0.8535
# Epoch 96/150
#  - 3s - loss: 0.8149 - mean_absolute_error: 0.4730 - acc: 0.8555
# Epoch 97/150
#  - 3s - loss: 0.8149 - mean_absolute_error: 0.4730 - acc: 0.8529
# Epoch 98/150
#  - 3s - loss: 0.8149 - mean_absolute_error: 0.4730 - acc: 0.8534
# Epoch 99/150
#  - 3s - loss: 0.8149 - mean_absolute_error: 0.4730 - acc: 0.8546
# Epoch 100/150
#  - 3s - loss: 0.8149 - mean_absolute_error: 0.4730 - acc: 0.8515
# Epoch 101/150
#  - 3s - loss: 0.8149 - mean_absolute_error: 0.4730 - acc: 0.8514
# Epoch 102/150
#  - 3s - loss: 0.8149 - mean_absolute_error: 0.4730 - acc: 0.8514
# Epoch 103/150
#  - 3s - loss: 0.8149 - mean_absolute_error: 0.4730 - acc: 0.8552
# Epoch 104/150
#  - 3s - loss: 0.8149 - mean_absolute_error: 0.4730 - acc: 0.8520
# Epoch 105/150
#  - 3s - loss: 0.8149 - mean_absolute_error: 0.4730 - acc: 0.8520
# Epoch 106/150
#  - 3s - loss: 0.8149 - mean_absolute_error: 0.4730 - acc: 0.8512
# Epoch 107/150
#  - 3s - loss: 0.8149 - mean_absolute_error: 0.4730 - acc: 0.8538
# Epoch 108/150
#  - 3s - loss: 0.8149 - mean_absolute_error: 0.4730 - acc: 0.8519
# Epoch 109/150
#  - 3s - loss: 0.8149 - mean_absolute_error: 0.4730 - acc: 0.8529
# Epoch 110/150
#  - 3s - loss: 0.8149 - mean_absolute_error: 0.4730 - acc: 0.8533
# Epoch 111/150
#  - 3s - loss: 0.8149 - mean_absolute_error: 0.4730 - acc: 0.8512
# Epoch 112/150
#  - 3s - loss: 0.8149 - mean_absolute_error: 0.4730 - acc: 0.8525
# Epoch 113/150
#  - 3s - loss: 0.8149 - mean_absolute_error: 0.4730 - acc: 0.8518
# Epoch 114/150
#  - 3s - loss: 0.8149 - mean_absolute_error: 0.4730 - acc: 0.8538
# Epoch 115/150
#  - 3s - loss: 0.8149 - mean_absolute_error: 0.4730 - acc: 0.8527
# Epoch 116/150
#  - 3s - loss: 0.8149 - mean_absolute_error: 0.4730 - acc: 0.8522
# Epoch 117/150
#  - 3s - loss: 0.8148 - mean_absolute_error: 0.4730 - acc: 0.8551
# Epoch 118/150
#  - 3s - loss: 0.8149 - mean_absolute_error: 0.4730 - acc: 0.8513
# Epoch 119/150
#  - 3s - loss: 0.8149 - mean_absolute_error: 0.4730 - acc: 0.8529
# Epoch 120/150
#  - 3s - loss: 0.8149 - mean_absolute_error: 0.4730 - acc: 0.8519
# Epoch 121/150
#  - 3s - loss: 0.8149 - mean_absolute_error: 0.4730 - acc: 0.8517
# Epoch 122/150
#  - 3s - loss: 0.8149 - mean_absolute_error: 0.4730 - acc: 0.8535
# Epoch 123/150
#  - 3s - loss: 0.8148 - mean_absolute_error: 0.4730 - acc: 0.8511
# Epoch 124/150
#  - 3s - loss: 0.8148 - mean_absolute_error: 0.4730 - acc: 0.8527
# Epoch 125/150
#  - 3s - loss: 0.8148 - mean_absolute_error: 0.4730 - acc: 0.8525
# Epoch 126/150
#  - 3s - loss: 0.8149 - mean_absolute_error: 0.4730 - acc: 0.8514
# Epoch 127/150
#  - 3s - loss: 0.8148 - mean_absolute_error: 0.4730 - acc: 0.8516
# Epoch 128/150
#  - 3s - loss: 0.8148 - mean_absolute_error: 0.4730 - acc: 0.8492
# Epoch 129/150
#  - 3s - loss: 0.8148 - mean_absolute_error: 0.4730 - acc: 0.8529
# Epoch 130/150
#  - 3s - loss: 0.8148 - mean_absolute_error: 0.4730 - acc: 0.8522
# Epoch 131/150
#  - 3s - loss: 0.8148 - mean_absolute_error: 0.4730 - acc: 0.8545
# Epoch 132/150
#  - 3s - loss: 0.8148 - mean_absolute_error: 0.4730 - acc: 0.8487
# Epoch 133/150
#  - 3s - loss: 0.8148 - mean_absolute_error: 0.4730 - acc: 0.8487
# Epoch 134/150
#  - 3s - loss: 0.8149 - mean_absolute_error: 0.4730 - acc: 0.8518
# Epoch 135/150
#  - 3s - loss: 0.8149 - mean_absolute_error: 0.4730 - acc: 0.8520
# Epoch 136/150
#  - 3s - loss: 0.8148 - mean_absolute_error: 0.4730 - acc: 0.8523
# Epoch 137/150
#  - 3s - loss: 0.8148 - mean_absolute_error: 0.4730 - acc: 0.8502
# Epoch 138/150
#  - 3s - loss: 0.8148 - mean_absolute_error: 0.4730 - acc: 0.8500
# Epoch 139/150
#  - 3s - loss: 0.8148 - mean_absolute_error: 0.4730 - acc: 0.8516
# Epoch 140/150
#  - 3s - loss: 0.8148 - mean_absolute_error: 0.4730 - acc: 0.8518
# Epoch 141/150
#  - 3s - loss: 0.8148 - mean_absolute_error: 0.4730 - acc: 0.8534
# Epoch 142/150
#  - 3s - loss: 0.8148 - mean_absolute_error: 0.4730 - acc: 0.8507
# Epoch 143/150
#  - 3s - loss: 0.8148 - mean_absolute_error: 0.4730 - acc: 0.8517
# Epoch 144/150
#  - 3s - loss: 0.8148 - mean_absolute_error: 0.4730 - acc: 0.8518
# Epoch 145/150
#  - 3s - loss: 0.8148 - mean_absolute_error: 0.4730 - acc: 0.8539
# Epoch 146/150
#  - 3s - loss: 0.8148 - mean_absolute_error: 0.4730 - acc: 0.8499
# Epoch 147/150
#  - 3s - loss: 0.8148 - mean_absolute_error: 0.4730 - acc: 0.8509
# Epoch 148/150
#  - 3s - loss: 0.8148 - mean_absolute_error: 0.4730 - acc: 0.8507
# Epoch 149/150
#  - 3s - loss: 0.8148 - mean_absolute_error: 0.4730 - acc: 0.8500
# Epoch 150/150
#  - 3s - loss: 0.8148 - mean_absolute_error: 0.4730 - acc: 0.8510
# Time: 36.00103961885004 minutes
#
# Best: 0.644150 using {'batch_size': 64, 'epochs': 150, 'optimizer': 'RMSprop'}
# 0.642257 (0.063550) with: {'batch_size': 32, 'epochs': 50, 'optimizer': 'RMSprop'}
# 0.466950 (0.097591) with: {'batch_size': 32, 'epochs': 50, 'optimizer': 'Adadelta'}
# 0.491000 (0.052842) with: {'batch_size': 32, 'epochs': 50, 'optimizer': 'Adam'}
# 0.482444 (0.035268) with: {'batch_size': 32, 'epochs': 50, 'optimizer': 'Adamax'}
# 0.607238 (0.062529) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'RMSprop'}
# 0.516581 (0.016241) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'Adadelta'}
# 0.577182 (0.070154) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'Adam'}
# 0.528238 (0.043028) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'Adamax'}
# 0.465394 (0.096226) with: {'batch_size': 32, 'epochs': 150, 'optimizer': 'RMSprop'}
# 0.583581 (0.044517) with: {'batch_size': 32, 'epochs': 150, 'optimizer': 'Adadelta'}
# 0.539337 (0.025005) with: {'batch_size': 32, 'epochs': 150, 'optimizer': 'Adam'}
# 0.537381 (0.005231) with: {'batch_size': 32, 'epochs': 150, 'optimizer': 'Adamax'}
# 0.541644 (0.009590) with: {'batch_size': 64, 'epochs': 50, 'optimizer': 'RMSprop'}
# 0.515557 (0.045619) with: {'batch_size': 64, 'epochs': 50, 'optimizer': 'Adadelta'}
# 0.543069 (0.138030) with: {'batch_size': 64, 'epochs': 50, 'optimizer': 'Adam'}
# 0.478351 (0.106629) with: {'batch_size': 64, 'epochs': 50, 'optimizer': 'Adamax'}
# 0.527687 (0.034798) with: {'batch_size': 64, 'epochs': 100, 'optimizer': 'RMSprop'}
# 0.500112 (0.017220) with: {'batch_size': 64, 'epochs': 100, 'optimizer': 'Adadelta'}
# 0.466013 (0.071378) with: {'batch_size': 64, 'epochs': 100, 'optimizer': 'Adam'}
# 0.552712 (0.004510) with: {'batch_size': 64, 'epochs': 100, 'optimizer': 'Adamax'}
# 0.644150 (0.074108) with: {'batch_size': 64, 'epochs': 150, 'optimizer': 'RMSprop'}
# 0.634431 (0.057795) with: {'batch_size': 64, 'epochs': 150, 'optimizer': 'Adadelta'}
# 0.637887 (0.064474) with: {'batch_size': 64, 'epochs': 150, 'optimizer': 'Adam'}
# 0.480731 (0.085215) with: {'batch_size': 64, 'epochs': 150, 'optimizer': 'Adamax'}
# 0.592600 (0.075302) with: {'batch_size': 128, 'epochs': 50, 'optimizer': 'RMSprop'}
# 0.565200 (0.018058) with: {'batch_size': 128, 'epochs': 50, 'optimizer': 'Adadelta'}
# 0.578168 (0.040931) with: {'batch_size': 128, 'epochs': 50, 'optimizer': 'Adam'}
# 0.544500 (0.008267) with: {'batch_size': 128, 'epochs': 50, 'optimizer': 'Adamax'}
# 0.533900 (0.023521) with: {'batch_size': 128, 'epochs': 100, 'optimizer': 'RMSprop'}
# 0.544413 (0.022433) with: {'batch_size': 128, 'epochs': 100, 'optimizer': 'Adadelta'}
# 0.547375 (0.003611) with: {'batch_size': 128, 'epochs': 100, 'optimizer': 'Adam'}
# 0.484557 (0.076383) with: {'batch_size': 128, 'epochs': 100, 'optimizer': 'Adamax'}
# 0.604449 (0.072881) with: {'batch_size': 128, 'epochs': 150, 'optimizer': 'RMSprop'}
# 0.526219 (0.020796) with: {'batch_size': 128, 'epochs': 150, 'optimizer': 'Adadelta'}
# 0.546218 (0.125370) with: {'batch_size': 128, 'epochs': 150, 'optimizer': 'Adam'}
# 0.490207 (0.078713) with: {'batch_size': 128, 'epochs': 150, 'optimizer': 'Adamax'}
