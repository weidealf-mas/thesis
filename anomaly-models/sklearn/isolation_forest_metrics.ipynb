# %%
import sys
sys.path.append('../../ml_utils')

import config as cfg
import data_utils as du
import numpy as np
import pandas as pd
import timeit
import matplotlib.pyplot as plt
import joblib
import sklearn

from sklearn.ensemble import IsolationForest
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score, f1_score

# %matplotlib inline

# %%
print("joblib (0.14.1): {}\n".format(joblib.__version__))
print("numpy (1.17.4): {}\n".format(np.__version__))
print("pandas (0.25.3): {}\n".format(pd.__version__))
print("sklearn (0.22): {}\n".format(sklearn.__version__))
# Out:
# joblib (0.14.1): 0.14.1
#
# numpy (1.17.4): 1.17.4
#
# pandas (0.25.3): 0.25.3
#
# sklearn (0.22): 0.22

# %% [markdown]
# ### Load and clean the data

# %%
log_data = './../../shared/data/swissid_authorize_logs_april_to_sept_2019.csv'

start = timeit.default_timer()
df = pd.read_csv(filepath_or_buffer=log_data, header=0, sep='\t', names=cfg.complete_feature_list, index_col=None)
stop = timeit.default_timer()

print("Original data frame size: {}\n".format(df.shape))
print("Time: {} seconds\n".format(stop - start))
# Out:
# Original data frame size: (12417597, 31)
#
# Time: 40.093010555999854 seconds

# %%
df = du.clean_data(df)
# Out:
# columns with NaN: loc_country_code
# loc_country_code is fixed

# %%
features = ['label_nr', 'src_software_sub_type', 'src_operating_system_name', 'src_hardware_type', 'response_status_code', 
            'oidc_client_id', 'oidc_scopes', 'oidc_ui_locales', 'loc_city', 'loc_country_code', 'date_weekday']

excludes = list(set(df.columns.tolist()) - set(features))

# %%
reduced_df = du.reduce_features(df, excludes)

print("reduced data frame size: {}\n".format(reduced_df.shape))
#display(reduced_df)
# Out:
# reduced data frame size: (12204748, 11)

# %%
print(reduced_df['label_nr'].value_counts())
# Out:
# 2    7412813
# 0    4769169
# 1      22766
# Name: label_nr, dtype: int64

# %% [markdown]
# ### Build a sampled dataframe having the same anomaly rate as the original dateset and collect the metrics data

# %%
iterations = 100
metrics = []
iter_values = []

# %%
sample_size= 200000
exclude = ['label_nr']

start_overall = timeit.default_timer()

for i in range(iterations):

    X_df, y_df, anomaly_rate, encoder = du.build_normal_anomaly_sample_df(reduced_df, sample_size, exclude)

    x_train, x_test, y_train, y_test = train_test_split(X_df, y_df, test_size = 0.2, random_state = 42)

    iforest_clf = IsolationForest(n_estimators=120, max_samples='auto', contamination=anomaly_rate)
    
    start_fitting = timeit.default_timer()
    iforest_clf.fit(x_train)
    stop_fitting = timeit.default_timer()
    
    fit_time = stop_fitting - start_fitting
    print("{0} Time to fit: {1:.2f} seconds".format(i, fit_time))
    
    y_scores = iforest_clf.decision_function(x_test)
    y_truth = y_test.values == cfg.label_anomaly_idx

    best_res, fpr_values, tpr_values, best_values = du.calc_best_threshold(y_truth, y_scores)

    iter_values.append(best_values)

    y_predictions = y_scores < best_res['best_auc_threshold']
    res, values = du.calc_metrics(y_truth, y_predictions)

    iter_values.append(values)

    y_predictions = y_scores < best_res['best_f1_score_threshold']
    res, values = du.calc_metrics(y_truth, y_predictions)

    iter_values.append(values)

    flat_list = [item for sublist in iter_values for item in sublist]
    
    flat_list.append(np.float64(fit_time))
# 73 Time to fit: 3.62 seconds
# 74 Time to fit: 3.60 seconds
# 75 Time to fit: 3.61 seconds
# 76 Time to fit: 3.66 seconds
# 77 Time to fit: 3.58 seconds
# 78 Time to fit: 3.64 seconds
# 79 Time to fit: 3.62 seconds
# 80 Time to fit: 3.60 seconds
# 81 Time to fit: 3.56 seconds
# 82 Time to fit: 3.62 seconds
# 83 Time to fit: 3.65 seconds
# 84 Time to fit: 3.59 seconds
# 85 Time to fit: 3.60 seconds
# 86 Time to fit: 3.60 seconds
# 87 Time to fit: 3.60 seconds
# 88 Time to fit: 3.61 seconds
# 89 Time to fit: 3.57 seconds
# 90 Time to fit: 3.57 seconds
# 91 Time to fit: 3.62 seconds
# 92 Time to fit: 3.58 seconds
# 93 Time to fit: 3.58 seconds
# 94 Time to fit: 3.60 seconds
# 95 Time to fit: 3.62 seconds
# 96 Time to fit: 3.64 seconds
# 97 Time to fit: 3.60 seconds
# 98 Time to fit: 3.55 seconds
# 99 Time to fit: 3.56 seconds
# Time: 898.49 seconds
#
# Time: 14.97 minutes

# %% [markdown]
# ### Calculate Metrics

# %%
metrics_df = du.create_metric_df(metrics, './isolation_forest_metrics.csv')
metrics_df.describe()
# Out:
#        best_f1_score_threshold    total  tot_anomaly    tot_normal  \
# count               100.000000    100.0   100.000000    100.000000
# mean                 -0.023786  40000.0   191.110000  39808.890000
# std                   0.010791      0.0    11.979692     11.979692
# min                  -0.051380  40000.0   166.000000  39774.000000
# 25%                  -0.030075  40000.0   183.000000  39802.000000
# 50%                  -0.022382  40000.0   192.000000  39808.000000
# 75%                  -0.017317  40000.0   198.000000  39817.000000
# max                   0.002986  40000.0   226.000000  39834.000000
#
#        tpr_recall   precision    accuracy    f1_score         fnr         tnr  \
# count  100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
# mean     0.800934    0.955242    0.998863    0.870631    0.199066    0.999812
# std      0.027137    0.044119    0.000245    0.026137    0.027137    0.000200
# min      0.720588    0.722222    0.997675    0.736544    0.127551    0.998745
# 25%      0.787009    0.942855    0.998725    0.858330    0.182636    0.999768
# 50%      0.804613    0.967837    0.998900    0.875708    0.195387    0.999874
# 75%      0.817364    0.982832    0.999031    0.886540    0.212991    0.999925
# max      0.872449    1.000000    0.999300    0.924324    0.279412    1.000000
#
#               fpr       t_pos       f_pos       f_neg         t_neg  \
# count  100.000000  100.000000  100.000000  100.000000    100.000000
# mean     0.000188  153.100000    7.480000   38.010000  39801.410000
# std      0.000200   11.310583    7.972782    5.547763     14.073469
# min      0.000000  129.000000    0.000000   25.000000  39761.000000
# 25%      0.000075  146.000000    3.000000   34.000000  39792.750000
# 50%      0.000126  153.500000    5.000000   37.000000  39802.000000
# 75%      0.000232  160.250000    9.250000   41.000000  39810.250000
# max      0.001255  180.000000   50.000000   57.000000  39834.000000
#
#               auc  time_to_fit
# count  100.000000   100.000000
# mean     0.900373     3.578659
# std      0.013573     0.028633
# min      0.860219     3.512977
# 25%      0.893414     3.557313
# 50%      0.902175     3.575334
# 75%      0.908580     3.596072
# max      0.936187     3.656407
