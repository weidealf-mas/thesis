# %%
import sys
sys.path.append('../../ml_utils')

import config as cfg
import data_utils as du
import vis_utils as vis
import autoencoder as aenc
import timeit
import joblib

import keras
from keras import optimizers
from keras import losses
from keras.models import Sequential, Model
from keras.layers import Dense, Input, Dropout, Embedding, LSTM
from keras.optimizers import RMSprop, Adam, Nadam
from keras.preprocessing import sequence
from keras.callbacks import TensorBoard
from keras import regularizers

import sklearn
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, roc_auc_score
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import classification_report

import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib

import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
# %matplotlib inline

import os
os.environ['CUDA_VISIBLE_DEVICES']='-1'

import tensorflow
# Out:
# Using TensorFlow backend.
# /home/administrator/anaconda3/envs/masterthesis/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/administrator/anaconda3/envs/masterthesis/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/administrator/anaconda3/envs/masterthesis/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/administrator/anaconda3/envs/masterthesis/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/administrator/anaconda3/envs/masterthesis/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/administrator/anaconda3/envs/masterthesis/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
print("Python: ", sys.version)
print("pandas: ", pd.__version__)
print("numpy: ", np.__version__)
print("seaborn: ", sns.__version__)
print("matplotlib: ", matplotlib.__version__)
print("sklearn: ", sklearn.__version__)
print("Keras: ", keras.__version__)
print("Tensorflow: ", tensorflow.__version__)
# Out:
# Python:  3.7.5 (default, Oct 25 2019, 15:51:11)
# [GCC 7.3.0]
# pandas:  0.25.3
# numpy:  1.17.4
# seaborn:  0.9.0
# matplotlib:  3.1.1
# sklearn:  0.22
# Keras:  2.2.4
# Tensorflow:  1.13.1

# %% [markdown]
# ### Load and clean the data

# %%
log_data = './../../shared/data/swissid_authorize_logs_april_to_sept_2019.csv'

start = timeit.default_timer()
df = pd.read_csv(filepath_or_buffer=log_data, header=0, sep='\t', names=cfg.complete_feature_list, index_col=None)
stop = timeit.default_timer()

print("Original data frame size: {}\n".format(df.shape))
print("Time: {} seconds\n".format(stop - start))
# Out:
# Original data frame size: (12417597, 31)
#
# Time: 39.711426982000376 seconds

# %%
df = du.clean_data(df)
# Out:
# columns with NaN: loc_country_code
# loc_country_code is fixed

# %%
features = ['label_nr', 'src_software_sub_type', 'src_operating_system_name', 'src_hardware_type', 'response_status_code', 
            'oidc_client_id', 'oidc_scopes', 'oidc_ui_locales', 'loc_city', 'loc_country_code', 'date_weekday']

excludes = list(set(df.columns.tolist()) - set(features))

# %%
reduced_df = du.reduce_features(df, excludes)

print("reduced data frame size: {}\n".format(reduced_df.shape))
#display(reduced_df)
# Out:
# reduced data frame size: (12204748, 11)

# %%
print(reduced_df['label_nr'].value_counts())
# Out:
# 2    7412813
# 0    4769169
# 1      22766
# Name: label_nr, dtype: int64

# %% [markdown]
# ### Model Training

# %%
sample_size= 500000
exclude = ['label_nr']

# load dataset
X_df, y_df, anomaly_rate, encoder = du.build_normal_anomaly_sample_df(reduced_df, sample_size, exclude, True, True, False, True)
x_train, x_test, y_train, y_test = train_test_split(X_df, y_df, test_size=0.3, random_state=42)

print(x_train.shape, 'train samples')
print(x_test.shape, 'test samples')
# Out:
# (350000, 10) train samples
# (150000, 10) test samples

# %%
#sparse autoencoder
from keras import regularizers

encoding_dim = 4
model = aenc.create_sparse_auto_encoder(x_train.shape[1], encoding_dim, 'relu', regularizers.l2(10e-5))
model.summary()
# Out:
# WARNING:tensorflow:From /home/administrator/anaconda3/envs/masterthesis/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 10)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 44
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                50
# =================================================================
# Total params: 94
# Trainable params: 94
# Non-trainable params: 0
# _________________________________________________________________

# %%
batch_size = 32
epochs = 25
optimizer='Adamax'

history = aenc.auto_encoder_fit(model, x_train, x_test, optimizer, epochs, batch_size)
# Out:
# WARNING:tensorflow:From /home/administrator/anaconda3/envs/masterthesis/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 350000 samples, validate on 150000 samples
# Epoch 1/25
# 350000/350000 [==============================] - 13s 36us/step - loss: 0.8766 - mean_absolute_error: 0.4891 - acc: 0.7427 - val_loss: 0.8557 - val_mean_absolute_error: 0.4734 - val_acc: 0.8647
# Epoch 2/25
# 350000/350000 [==============================] - 13s 36us/step - loss: 0.8466 - mean_absolute_error: 0.4715 - acc: 0.8990 - val_loss: 0.8507 - val_mean_absolute_error: 0.4713 - val_acc: 0.8951
# Epoch 3/25
# 350000/350000 [==============================] - 13s 36us/step - loss: 0.8436 - mean_absolute_error: 0.4704 - acc: 0.9071 - val_loss: 0.8488 - val_mean_absolute_error: 0.4709 - val_acc: 0.9145
# Epoch 4/25
# 350000/350000 [==============================] - 13s 36us/step - loss: 0.8421 - mean_absolute_error: 0.4700 - acc: 0.9079 - val_loss: 0.8478 - val_mean_absolute_error: 0.4706 - val_acc: 0.9062
# Epoch 5/25
# 350000/350000 [==============================] - 12s 35us/step - loss: 0.8414 - mean_absolute_error: 0.4699 - acc: 0.9059 - val_loss: 0.8471 - val_mean_absolute_error: 0.4704 - val_acc: 0.8905
# Epoch 6/25
# 350000/350000 [==============================] - 12s 36us/step - loss: 0.8409 - mean_absolute_error: 0.4698 - acc: 0.9044 - val_loss: 0.8468 - val_mean_absolute_error: 0.4703 - val_acc: 0.9079
# Epoch 7/25
# 350000/350000 [==============================] - 13s 36us/step - loss: 0.8406 - mean_absolute_error: 0.4697 - acc: 0.9072 - val_loss: 0.8465 - val_mean_absolute_error: 0.4702 - val_acc: 0.9138
# Epoch 8/25
# 350000/350000 [==============================] - 12s 36us/step - loss: 0.8403 - mean_absolute_error: 0.4696 - acc: 0.9086 - val_loss: 0.8463 - val_mean_absolute_error: 0.4703 - val_acc: 0.9099
# Epoch 9/25
# 350000/350000 [==============================] - 12s 35us/step - loss: 0.8401 - mean_absolute_error: 0.4695 - acc: 0.9092 - val_loss: 0.8460 - val_mean_absolute_error: 0.4701 - val_acc: 0.9144
# Epoch 10/25
# 350000/350000 [==============================] - 12s 35us/step - loss: 0.8399 - mean_absolute_error: 0.4695 - acc: 0.9098 - val_loss: 0.8459 - val_mean_absolute_error: 0.4700 - val_acc: 0.9096
# Epoch 11/25
# 350000/350000 [==============================] - 12s 35us/step - loss: 0.8398 - mean_absolute_error: 0.4695 - acc: 0.9103 - val_loss: 0.8458 - val_mean_absolute_error: 0.4700 - val_acc: 0.9107
# Epoch 12/25
# 350000/350000 [==============================] - 12s 35us/step - loss: 0.8397 - mean_absolute_error: 0.4695 - acc: 0.9101 - val_loss: 0.8457 - val_mean_absolute_error: 0.4701 - val_acc: 0.9159
# Epoch 13/25
# 350000/350000 [==============================] - 12s 35us/step - loss: 0.8396 - mean_absolute_error: 0.4694 - acc: 0.9096 - val_loss: 0.8456 - val_mean_absolute_error: 0.4700 - val_acc: 0.9115
# Epoch 14/25
# 350000/350000 [==============================] - 13s 36us/step - loss: 0.8395 - mean_absolute_error: 0.4694 - acc: 0.9102 - val_loss: 0.8455 - val_mean_absolute_error: 0.4700 - val_acc: 0.9157
# Epoch 15/25
# 350000/350000 [==============================] - 13s 37us/step - loss: 0.8394 - mean_absolute_error: 0.4694 - acc: 0.9101 - val_loss: 0.8454 - val_mean_absolute_error: 0.4700 - val_acc: 0.9083
# Epoch 16/25
# 350000/350000 [==============================] - 13s 36us/step - loss: 0.8393 - mean_absolute_error: 0.4694 - acc: 0.9102 - val_loss: 0.8453 - val_mean_absolute_error: 0.4700 - val_acc: 0.9090
# Epoch 17/25
# 350000/350000 [==============================] - 13s 36us/step - loss: 0.8393 - mean_absolute_error: 0.4694 - acc: 0.9090 - val_loss: 0.8453 - val_mean_absolute_error: 0.4699 - val_acc: 0.9135
# Epoch 18/25
# 350000/350000 [==============================] - 13s 36us/step - loss: 0.8392 - mean_absolute_error: 0.4693 - acc: 0.9092 - val_loss: 0.8452 - val_mean_absolute_error: 0.4699 - val_acc: 0.9106
# Epoch 19/25
# 350000/350000 [==============================] - 13s 37us/step - loss: 0.8391 - mean_absolute_error: 0.4693 - acc: 0.9093 - val_loss: 0.8452 - val_mean_absolute_error: 0.4699 - val_acc: 0.9062
# Epoch 20/25
# 350000/350000 [==============================] - 13s 36us/step - loss: 0.8391 - mean_absolute_error: 0.4693 - acc: 0.9095 - val_loss: 0.8451 - val_mean_absolute_error: 0.4699 - val_acc: 0.9087
# Epoch 21/25
# 350000/350000 [==============================] - 13s 36us/step - loss: 0.8390 - mean_absolute_error: 0.4692 - acc: 0.9081 - val_loss: 0.8451 - val_mean_absolute_error: 0.4699 - val_acc: 0.9094
# Epoch 22/25
# 350000/350000 [==============================] - 13s 37us/step - loss: 0.8390 - mean_absolute_error: 0.4692 - acc: 0.9083 - val_loss: 0.8450 - val_mean_absolute_error: 0.4697 - val_acc: 0.9043
# Epoch 23/25
# 350000/350000 [==============================] - 13s 37us/step - loss: 0.8389 - mean_absolute_error: 0.4692 - acc: 0.9081 - val_loss: 0.8450 - val_mean_absolute_error: 0.4698 - val_acc: 0.9039
# Epoch 24/25
# 350000/350000 [==============================] - 13s 37us/step - loss: 0.8389 - mean_absolute_error: 0.4692 - acc: 0.9066 - val_loss: 0.8449 - val_mean_absolute_error: 0.4699 - val_acc: 0.8936
# Epoch 25/25
# 350000/350000 [==============================] - 13s 37us/step - loss: 0.8388 - mean_absolute_error: 0.4692 - acc: 0.9057 - val_loss: 0.8449 - val_mean_absolute_error: 0.4697 - val_acc: 0.9188

# %%
score = model.evaluate(x_test, x_test, verbose=1)

for i, metric in enumerate(model.metrics_names):
    print('Test ' + metric + ':', score[i])
# Out:
# 150000/150000 [==============================] - 1s 9us/step
# Test loss: 0.8448874793084462
# Test mean_absolute_error: 0.469737234656016
# Test acc: 0.9188333333333333

# %% [markdown]
# # Model Evaluation

# %% [markdown]
# ## Model Loss

# %%
sns.set(style='whitegrid', palette='muted', font_scale=1.0)

plt.plot(history.history['loss'], linewidth=2, label='Train')
plt.plot(history.history['val_loss'], linewidth=2, label='Validation')
plt.legend(loc='upper right')
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
#plt.ylim(ymin=0.70,ymax=1)
plt.show()

# %%
sns.set(style='whitegrid', palette='muted', font_scale=1.0)

plt.plot(history.history['acc'], linewidth=2, label='Train')
plt.plot(history.history['val_acc'], linewidth=2, label='Validation')
plt.legend(loc='upper right')
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
#plt.ylim(ymin=0.70,ymax=1)
plt.show()

# %% [markdown]
# ## Reconstruction Error Check

# %%
x_test_predictions = model.predict(x_test)
mse = np.mean(np.power(x_test - x_test_predictions, 2), axis=1)
error_df = pd.DataFrame({'Reconstruction_error': mse, 'True_class': y_test})
error_df.describe()
# Out:
#        Reconstruction_error     True_class
# count         150000.000000  150000.000000
# mean               0.843976       0.004893
# std                4.267835       0.069781
# min                0.061085       0.000000
# 25%                0.198337       0.000000
# 50%                0.317486       0.000000
# 75%                0.488172       0.000000
# max              240.661941       1.000000

# %% [markdown]
# ## ROC Curve Check

# %% [markdown]
# Receiver operating characteristic curves are an expected output of most binary classifiers. Since we have an imbalanced data set they are somewhat less useful. Why? Because you can generate a pretty good-looking curve by just simply guessing everything is the normal case because there are so proportionally few cases of fraud. Without getting into detail, this is something called the Accuracy Paradox.

# %%
from sklearn.metrics import confusion_matrix, precision_recall_curve
from sklearn.metrics import recall_score, classification_report, auc, roc_curve
from sklearn.metrics import precision_recall_fscore_support, f1_score

# %%
fpr, tpr, thresholds = roc_curve(error_df.True_class, error_df.Reconstruction_error)
roc_auc = auc(fpr, tpr)

plt.plot(fpr, tpr, linewidth=2, label='AUC = %0.3f'% roc_auc)
plt.plot([0,1],[0,1], linewidth=2)

plt.xlim([-0.01, 1])
plt.ylim([0, 1.01])
plt.legend(loc='lower right')
plt.title('Receiver operating characteristic curve (ROC)')
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %% [markdown]
# ## Recall vs. Precision Thresholding

# %% [markdown]
# Precision and recall are the eternal tradeoff in data science, so at some point you have to draw an arbitrary line, or a threshold. Where this line will be drawn is essentially a business decision. In this case, you are trading off the cost between missing a fraudulent transaction and the cost of falsely flagging the transaction as a fraudulent even when it is not. Add those two weights to the calculation and you can come up with some theoretical optimal solution. This is rarely the way it is done in practice, however, as it is hard to quantify a lot of those costs (such as customer annoyance at getting fraud alerts too frequently), or because of various structural, technical, or business rules preventing the optimized solution from being chosen.

# %%
precision_rt, recall_rt, threshold_rt = precision_recall_curve(error_df.True_class, error_df.Reconstruction_error)

plt.plot(recall_rt, precision_rt, linewidth=2, label='Precision-Recall curve')
plt.title('Recall vs Precision')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.show()

# %%
plt.plot(threshold_rt, precision_rt[1:], label="Precision",linewidth=2)
plt.plot(threshold_rt, recall_rt[1:], label="Recall",linewidth=2)
plt.title('Precision and recall for different threshold values')
plt.xlabel('Threshold')
plt.ylabel('Precision/Recall')
plt.legend()
plt.show()

# %% [markdown]
# ## Balance of Data Visualization

# %%
y_pred = model.predict(x_test)

# %%
thres, f1_max, p, r, sup, acc = aenc.calc_metrics(x_test, y_test, y_pred)

print("threshold: {}".format(thres))
print("F1-Score: {}".format(f1_max))
print("Precision: {}".format(p))
print("Recall: {}".format(r))
print("Support: {}".format(sup))
print("Accuracy: {}".format(acc))
# Out:
# /home/administrator/anaconda3/envs/masterthesis/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1268: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# threshold: 11.299999999999976
# F1-Score: 0.7434447300771208
# Precision: 0.597027250206441
# Recall: 0.9850136239782016
# Support: 734
# Accuracy: 0.9966733333333333

# %%
y_class, errors = aenc.classify(x_test, y_pred, thres)

# %%
roc_auc_score(y_test, y_class)
# Out:
# 0.9908721463586155

# %% [markdown]
# ## Confusion Matrix

# %%
viz = vis.Visualization()

viz.draw_confusion_matrix(y_test, y_class)

# %% [markdown]
# ## Reconstruction Error vs Threshold Check

# %%
viz.draw_anomaly(y_test, errors, thres)

# %%
path_model = './../../shared/models/autoencoder/sparse_autoencoder_model_l2.hdf5'
path_enc = './../../shared/models/autoencoder/sparse_autoencoder_encoder_all_l2.pkl'

model.save(path_model)
joblib.dump(encoder, path_enc)
# Out:
# ['./../../shared/models/autoencoder/sparse_autoencoder_encoder_all_l2.pkl']
