# %%
import sys
sys.path.append('../../ml_utils')

import config as cfg
import data_utils as du
import numpy as np
import pandas as pd
import timeit
import matplotlib.pyplot as plt
import joblib
import sklearn

from sklearn.svm import OneClassSVM
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score, f1_score

# %matplotlib inline

# %%
print("joblib (0.14.1): {}\n".format(joblib.__version__))
print("numpy (1.17.4): {}\n".format(np.__version__))
print("pandas (0.25.3): {}\n".format(pd.__version__))
print("sklearn (0.22): {}\n".format(sklearn.__version__))
# Out:
# joblib (0.14.1): 0.14.1
#
# numpy (1.17.4): 1.17.4
#
# pandas (0.25.3): 0.25.3
#
# sklearn (0.22): 0.22

# %% [markdown]
# ### Load and clean the data

# %%
log_data = './../../shared/data/swissid_authorize_logs_april_to_sept_2019.csv'

start = timeit.default_timer()
df = pd.read_csv(filepath_or_buffer=log_data, header=0, sep='\t', names=cfg.complete_feature_list, index_col=None)
stop = timeit.default_timer()

print("Original data frame size: {}\n".format(df.shape))
print("Time: {} seconds\n".format(stop - start))
# Out:
# Original data frame size: (12417597, 31)
#
# Time: 39.41910548499982 seconds

# %%
df = du.clean_data(df)
# Out:
# columns with NaN: loc_country_code
# loc_country_code is fixed

# %%
features = ['label_nr', 'src_software_sub_type', 'src_operating_system_name', 'src_hardware_type', 'response_status_code', 
            'oidc_client_id', 'oidc_scopes', 'oidc_ui_locales', 'loc_city', 'loc_country_code', 'date_weekday']

excludes = list(set(df.columns.tolist()) - set(features))

# %%
reduced_df = du.reduce_features(df, excludes)

print("reduced data frame size: {}\n".format(reduced_df.shape))
#display(reduced_df)
# Out:
# reduced data frame size: (12204748, 11)

# %%
print(reduced_df['label_nr'].value_counts())
# Out:
# 2    7412813
# 0    4769169
# 1      22766
# Name: label_nr, dtype: int64

# %% [markdown]
# ### Build a sampled dataframe having the same anomaly rate as the original dateset and collect the metrics data

# %%
iterations = 100
metrics = []
iter_values = []

# %%
sample_size= 200000
novelties_size = 10000


exclude = ['label_nr']

start_overall = timeit.default_timer()

for i in range(iterations):

    X_df, y_df, X_val_df, y_val_df, X_nov_df, y_nov_df, encoder = du.build_normal_and_novelty_sample_df(reduced_df, sample_size, 1000, novelties_size, exclude)

    x_train, x_test, y_train, y_test = train_test_split(X_df, y_df, test_size = 0.2, random_state = 42)

    ocsvm_clf = OneClassSVM(kernel='rbf', gamma=0.00005, nu=0.001, cache_size=5000)
    
    start_fitting = timeit.default_timer()
    ocsvm_clf.fit(x_train)
    stop_fitting = timeit.default_timer()
    
    fit_time = stop_fitting - start_fitting
    print("{0} Time to fit: {1:.2f} seconds".format(i, fit_time))
    
    y_scores = ocsvm_clf.score_samples(X_nov_df)
    
    y_truth = y_nov_df.values == cfg.label_anomaly_idx

    best_res, fpr_values, tpr_values, best_values = du.calc_best_threshold(y_truth, y_scores, du.step(y_scores), True)

    iter_values.append(best_values)

    y_predictions = y_scores < best_res['best_auc_threshold']
    res, values = du.calc_metrics(y_truth, y_predictions)

    iter_values.append(values)

    y_predictions = y_scores < best_res['best_f1_score_threshold']
    res, values = du.calc_metrics(y_truth, y_predictions)

    iter_values.append(values)

# 72 Time to fit: 3.35 seconds
# 73 Time to fit: 3.33 seconds
# 74 Time to fit: 74.01 seconds
# 75 Time to fit: 63.52 seconds
# 76 Time to fit: 3.14 seconds
# 77 Time to fit: 3.23 seconds
# 78 Time to fit: 41.65 seconds
# 79 Time to fit: 103.06 seconds
# 80 Time to fit: 3.27 seconds
# 81 Time to fit: 61.25 seconds
# 82 Time to fit: 53.44 seconds
# 83 Time to fit: 69.44 seconds
# 84 Time to fit: 120.35 seconds
# 85 Time to fit: 46.83 seconds
# 86 Time to fit: 76.66 seconds
# 87 Time to fit: 46.49 seconds
# 88 Time to fit: 3.27 seconds
# 89 Time to fit: 52.33 seconds
# 90 Time to fit: 45.80 seconds
# 91 Time to fit: 42.81 seconds
# 92 Time to fit: 50.09 seconds
# 93 Time to fit: 50.02 seconds
# 94 Time to fit: 3.33 seconds
# 95 Time to fit: 43.79 seconds
# 96 Time to fit: 60.49 seconds
# 97 Time to fit: 3.23 seconds
# 98 Time to fit: 45.51 seconds
# 99 Time to fit: 61.87 seconds
# Time: 7880.40 seconds
#
# Time: 131.34 minutes

# %% [markdown]
# ### Calculate Metrics

# %%
metrics_df = du.create_metric_df(metrics, './one_class_svm_metrics.csv')
metrics_df.describe()
# Out:
#        best_f1_score_threshold    total  tot_anomaly  tot_normal  tpr_recall  \
# count               100.000000    100.0        100.0       100.0  100.000000
# mean                  1.391836  10000.0       5000.0      5000.0    0.946538
# std                   0.005763      0.0          0.0         0.0    0.016055
# min                   1.379200  10000.0       5000.0      5000.0    0.909200
# 25%                   1.387964  10000.0       5000.0      5000.0    0.937350
# 50%                   1.391668  10000.0       5000.0      5000.0    0.954400
# 75%                   1.394988  10000.0       5000.0      5000.0    0.958250
# max                   1.408705  10000.0       5000.0      5000.0    0.964400
#
#         precision    accuracy    f1_score         fnr         tnr         fpr  \
# count  100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
# mean     0.976275    0.961205    0.960802    0.053462    0.975872    0.024128
# std      0.029468    0.015741    0.014824    0.016055    0.032600    0.032600
# min      0.840112    0.888000    0.895366    0.035600    0.817600    0.001000
# 25%      0.968994    0.954950    0.954032    0.041750    0.969450    0.006450
# 50%      0.987937    0.964300    0.963238    0.045600    0.988600    0.011400
# 75%      0.993291    0.972600    0.972138    0.062650    0.993550    0.030550
# max      0.998907    0.978000    0.977569    0.090800    0.999000    0.182400
#
#              t_pos       f_pos       f_neg        t_neg         auc  \
# count   100.000000  100.000000  100.000000   100.000000  100.000000
# mean   4732.690000  120.640000  267.310000  4879.360000    0.961205
# std      80.273736  163.002046   80.273736   163.002046    0.015741
# min    4546.000000    5.000000  178.000000  4088.000000    0.888000
# 25%    4686.750000   32.250000  208.750000  4847.250000    0.954950
# 50%    4772.000000   57.000000  228.000000  4943.000000    0.964300
# 75%    4791.250000  152.750000  313.250000  4967.750000    0.972600
# max    4822.000000  912.000000  454.000000  4995.000000    0.978000
#
#        time_to_fit
# count   100.000000
# mean     45.942068
# std      30.193105
# min       3.093963
# 25%      30.556394
# 50%      50.078188
# 75%      58.464476
# max     120.378291
